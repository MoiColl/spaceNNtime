# %% [markdown]
# # Slendr simulations
#
# This notebook contains the simulations produced with *slendr* for the spaceNNtime project.
#
# <a name="Home"></a>
#
# ## Contents
#
# 0. [ Library and packages ](#Lib)
# 1. [ Functions ](#Fun)
#     + 1. [Python Functions](#Pyf)
#     + 2. [R Functions](#Rfu)
# 2. [ Slendr - european pop history, single locus and temporal uniform sampling ](#Sle)
#     + 1. [ Setup map and regions ](#Map)
#     + 2. [ Setup populations, their demographic history and admixtures ](#Pop)
#     + 3. [ Compile the model ](#Com)
#     + 4. [ Explore the model ](#Exp)
#     + 5. [ Sampling ](#Saa)
#     + 6. [ Simulate ](#Sim)
#
# <a name="Lib"></a>
# ## 0. Library and packages

# %%
import sys
import pandas as pd
import numpy as np
import tskit
import msprime
import pyslim

from rpy2.robjects import r, pandas2ri

# %load_ext rpy2.ipython
pandas2ri.activate()
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# .libPaths()
# Out:
# [1] "/maps/projects/racimolab/people/qxz396/spaceNNtime/backup/environments/renv/library/R-4.1/x86_64-redhat-linux-gnu"
# [2] "/maps/projects/racimolab/people/qxz396/miniconda3/envs/sNNt_slendr/lib/R/library"

# %%
# %%R
# .libPaths(c("/maps/projects/racimolab/people/qxz396/spaceNNtime/environments/renv/library/R-4.1/x86_64-redhat-linux-gnu", "/tmp/Rtmp9Hi1cZ/renv-system-library"))
#
# library(ggplot2)
# library(cowplot)
# library(slendr)
# library(sf)
# library(tidyverse)
# library(rnaturalearth)
# library(rnaturalearthdata)
#
# simulation_path = "/maps/projects/racimolab/people/qxz396/spaceNNtime/data/europe"

# %%
# %%R
# .libPaths()
# Out:
# [1] "/maps/projects/racimolab/people/qxz396/spaceNNtime/backup/environments/renv/library/R-4.1/x86_64-redhat-linux-gnu"
# [2] "/maps/projects/racimolab/people/qxz396/miniconda3/envs/sNNt_slendr/lib/R/library"

# %% [markdown]
# [<img src="arrow.png" width="100" style="float: left;">](#Home) &nbsp;
#
# &nbsp;
#
# <a name="Fun"></a>
# ## 1. Functions
#
# <a name="Pfu"></a>
# ### A. Python Functions

# %% [markdown]
# <a name="Rfu"></a>
# ### B. R Functions

# %%
# %%R
#
# sampling_uniform_intime <- function(n, pop_timing, pops_list, gen_time = 30, min = 500, max = 51000){
#     samples  <- data.frame()
#     i = 0
#     while(samples %>% nrow() < 1 || sum(samples$n) < n){
#
#         t = round(runif(n = 1, min = min, max = max))
#
#         if(pop_timing %>% dplyr::filter(start > t+gen_time, end < t-gen_time) %>% nrow() > 0){
#             i = i + 1
#
#             pop_idx  = pop_timing %>%
#                             dplyr::filter(start > t+gen_time, end < t-gen_time) %>%
#                             dplyr::sample_n(1) %>%
#                             dplyr::pull(index)
#
#             pop_nam  = pop_timing %>% dplyr::filter(index == pop_idx) %>% dplyr::pull(pop)
#
#             if(samples %>% nrow() > 1 && samples %>% dplyr::filter(time  == t, pop == pop_nam) %>% nrow() > 0){
#
#                 samples <- samples %>% dplyr::mutate(n = ifelse(time == t & pop == pop_nam, n+1, n))
#
#             }else{
#
#                 samples <- rbind(samples, schedule_sampling(model, times = t, list( pops_list[[pop_idx]], 1 )))
#             }
#         }
#     }
#     return(samples)
# }

# %% [markdown]
# [<img src="arrow.png" width="100" style="float: left;">](#Home) &nbsp;
#
# &nbsp;
#
# <a name="Sle"></a>
# ## 2. Slendr - european pop history, single locus and temporal uniform sampling
#
# <a name="Map"></a>
# ### A. Setup map and regions

# %%
# %%R
# map <- world(xrange = c(-15, 60), yrange = c(20, 65),crs = "EPSG:3035")
# print(map)
# plot_map(map)
# Out:
# R[write to console]: Error in loadNamespace(x) : there is no package called ‘rgdal’
# Error in loadNamespace(x) : there is no package called ‘rgdal’
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/ipython/rmagic.py in eval(self, code)
#     267                 # Need the newline in case the last line in code is a comment.
# --> 268                 value, visible = ro.r("withVisible({%s\n})" % code)
#     269             except (ri.embedded.RRuntimeError, ValueError) as exception:
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     437         p = rinterface.parse(string)
# --> 438         res = self.eval(p)
#     439         return conversion.rpy2py(res)
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     197                 kwargs[r_k] = v
# --> 198         return (super(SignatureTranslatedFunction, self)
#     199                 .__call__(*args, **kwargs))
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     124                 new_kwargs[k] = conversion.py2rpy(v)
# --> 125         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     126         res = conversion.rpy2py(res)
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      44     def _(*args, **kwargs):
# ---> 45         cdata = function(*args, **kwargs)
#      46         # TODO: test cdata is of the expected CType
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/rinterface.py in __call__(self, *args, **kwargs)
#     679             if error_occured[0]:
# --> 680                 raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     681         return res
#
# RRuntimeError: Error in loadNamespace(x) : there is no package called ‘rgdal’
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# /tmp/ipykernel_2285517/1053832090.py in <module>
# ----> 1 get_ipython().run_cell_magic('R', '', 'map <- world(xrange = c(-15, 60), yrange = c(20, 65),crs = "EPSG:3035")\nprint(map)\nplot_map(map)\n')
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# -> 2419                 result = fn(*args, **kwargs)
#    2420             return result
#    2421
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/ipython/rmagic.py in R(self, line, cell, local_ns)
#     781             if not e.stdout.endswith(e.err):
#     782                 print(e.err)
# --> 783             raise e
#     784         finally:
#     785             if self.device in ['png', 'svg']:
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/ipython/rmagic.py in R(self, line, cell, local_ns)
#     761                     return_output = False
#     762             else:
# --> 763                 text_result, result, visible = self.eval(code)
#     764                 text_output += text_result
#     765                 if visible:
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/ipython/rmagic.py in eval(self, code)
#     270                 # Otherwise next return seems to have copy of error.
#     271                 warning_or_other_msg = self.flush()
# --> 272                 raise RInterpreterError(code, str(exception),
#     273                                         warning_or_other_msg)
#     274             text_output = self.flush()
#
# RInterpreterError: Failed to parse and evaluate line 'map <- world(xrange = c(-15, 60), yrange = c(20, 65),crs = "EPSG:3035")\nprint(map)\nplot_map(map)\n'.
# R error message: 'Error in loadNamespace(x) : there is no package called ‘rgdal’'

# %%
# %%R
#
# africa   <- region("Africa",   map, polygon = list(c(-18, 20), c(40, 20), c(30, 33),c(20, 32), c(10, 35), c(-8, 35)))
# europe   <- region("Europe",   map, polygon = list(c(-8, 35), c(-5, 36), c(10, 38), c(20, 35), c(25, 35),c(33, 45), c(20, 58), c(-5, 60), c(-15, 50)))
# anatolia <- region("Anatolia", map, polygon = list(c(28, 35), c(40, 35), c(42, 40), c(30, 43), c(27, 40), c(25, 38)))
#
# plot_map(africa, europe, anatolia)
# Out:
# R[write to console]: Error in !is.null(map) && nrow(map) : invalid 'y' type in 'x && y'
# Error in !is.null(map) && nrow(map) : invalid 'y' type in 'x && y'
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/ipython/rmagic.py in eval(self, code)
#     267                 # Need the newline in case the last line in code is a comment.
# --> 268                 value, visible = ro.r("withVisible({%s\n})" % code)
#     269             except (ri.embedded.RRuntimeError, ValueError) as exception:
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     437         p = rinterface.parse(string)
# --> 438         res = self.eval(p)
#     439         return conversion.rpy2py(res)
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     197                 kwargs[r_k] = v
# --> 198         return (super(SignatureTranslatedFunction, self)
#     199                 .__call__(*args, **kwargs))
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     124                 new_kwargs[k] = conversion.py2rpy(v)
# --> 125         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     126         res = conversion.rpy2py(res)
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      44     def _(*args, **kwargs):
# ---> 45         cdata = function(*args, **kwargs)
#      46         # TODO: test cdata is of the expected CType
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/rinterface.py in __call__(self, *args, **kwargs)
#     679             if error_occured[0]:
# --> 680                 raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     681         return res
#
# RRuntimeError: Error in !is.null(map) && nrow(map) : invalid 'y' type in 'x && y'
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# /tmp/ipykernel_2285517/2623932129.py in <module>
# ----> 1 get_ipython().run_cell_magic('R', '', '\nafrica   <- region("Africa",   map, polygon = list(c(-18, 20), c(40, 20), c(30, 33),c(20, 32), c(10, 35), c(-8, 35)))\neurope   <- region("Europe",   map, polygon = list(c(-8, 35), c(-5, 36), c(10, 38), c(20, 35), c(25, 35),c(33, 45), c(20, 58), c(-5, 60), c(-15, 50)))\nanatolia <- region("Anatolia", map, polygon = list(c(28, 35), c(40, 35), c(42, 40), c(30, 43), c(27, 40), c(25, 38)))\n\nplot_map(africa, europe, anatolia)\n')
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# -> 2419                 result = fn(*args, **kwargs)
#    2420             return result
#    2421
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/ipython/rmagic.py in R(self, line, cell, local_ns)
#     781             if not e.stdout.endswith(e.err):
#     782                 print(e.err)
# --> 783             raise e
#     784         finally:
#     785             if self.device in ['png', 'svg']:
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/ipython/rmagic.py in R(self, line, cell, local_ns)
#     761                     return_output = False
#     762             else:
# --> 763                 text_result, result, visible = self.eval(code)
#     764                 text_output += text_result
#     765                 if visible:
#
# ~/miniconda3/envs/sNNt_slendr/lib/python3.9/site-packages/rpy2/ipython/rmagic.py in eval(self, code)
#     270                 # Otherwise next return seems to have copy of error.
#     271                 warning_or_other_msg = self.flush()
# --> 272                 raise RInterpreterError(code, str(exception),
#     273                                         warning_or_other_msg)
#     274             text_output = self.flush()
#
# RInterpreterError: Failed to parse and evaluate line '\nafrica   <- region("Africa",   map, polygon = list(c(-18, 20), c(40, 20), c(30, 33),c(20, 32), c(10, 35), c(-8, 35)))\neurope   <- region("Europe",   map, polygon = list(c(-8, 35), c(-5, 36), c(10, 38), c(20, 35), c(25, 35),c(33, 45), c(20, 58), c(-5, 60), c(-15, 50)))\nanatolia <- region("Anatolia", map, polygon = list(c(28, 35), c(40, 35), c(42, 40), c(30, 43), c(27, 40), c(25, 38)))\n\nplot_map(africa, europe, anatolia)\n'.
# R error message: "Error in !is.null(map) && nrow(map) : invalid 'y' type in 'x && y'"

# %% [markdown]
# [<img src="arrow.png" width="100" style="float: left;">](#Home) &nbsp;
#
# &nbsp;
#
# <a name="Pop"></a>
# ### B. Setup populations, their demographic history and admixtures

# %%
# %%R
#
# # African ancestral population
# # ----------------------------
#
# afr <- population("AFR", parent = "ancestor", time = 52000, N = 3000, map = map, polygon = africa)
#
# # population of the first migrants out of Africa
# # ----------------------------------------------
#
# ooa <- population("OOA", parent = afr, time = 51000, N = 500, remove = 25000, center = c(33, 30), radius = 400e3) %>%
#             move(trajectory = list(c(40, 30), c(50, 30), c(60, 40)), start = 50000, end = 40000, snapshots = 20)
#
# # Eastern hunter-gatherers
# # ------------------------
#
# ehg <- population("EHG", parent = ooa, time = 28000, N = 1000, remove = 6000, polygon = list(c(26, 55), c(38, 53), c(48, 53), c(60, 53), c(60, 60), c(48, 63), c(38, 63), c(26, 60)))
#
# # European population
# # -------------------
#
# eur <- population( name = "EUR", parent = ehg, time = 25000, N = 2000, polygon = europe)
#
# # Anatolian farmers
# # -----------------
#
# ana <- population( name = "ANA", time = 28000, N = 3000, parent = ooa, remove = 4000, center = c(34, 38), radius = 500e3, polygon = anatolia) %>%
#         expand_range(by = 2500e3, start = 10000, end = 7000, polygon = join(europe, anatolia), snapshots = 20)
#
# # Yamnaya steppe population
# # -------------------------
#
# yam <- population( name = "YAM", time = 7000, N = 500, parent = ehg, remove = 2500, polygon = list(c(26, 50), c(38, 49), c(48, 50), c(48, 56), c(38, 59), c(26, 56))) %>%
#             move(trajectory = list(c(15, 50)), start = 5000, end = 3000, snapshots = 10)
#
# # Gene flow events
# # ----------------
#
# gf <- list(
#   gene_flow(from = ana, to = yam, rate = 0.5,  start = 6500, end = 6400, overlap = FALSE),
#   gene_flow(from = ana, to = eur, rate = 0.5,  start = 8000, end = 6000),
#   gene_flow(from = yam, to = eur, rate = 0.75, start = 4000, end = 3000)
# )
#
# plot_map(afr, ooa, ehg, eur, ana, yam)

# %% [markdown]
# [<img src="arrow.png" width="100" style="float: left;">](#Home) &nbsp;
#
# &nbsp;
#
# <a name="Com"></a>
# ### C. Compile the model

# %%
# %%bash
#
# mkdir -p /projects/racimolab/people/qxz396/spaceNNtime/data/europe

# %%
# %%R
#
# if(file.exists(paste(simulation_path, "/populations.tsv", sep = "" ))){
#     model <- read_model(simulation_path)
# }else{
#     model <- compile_model(
#       populations      = list(afr, ooa, ehg, eur, ana, yam),
#       gene_flow        = gf,
#       generation_time  = 30,
#       resolution       = 10e3,                     # resolution in meters per pixel
#       competition      = 130e3, mating = 100e3,    # spatial interaction in SLiM
#       dispersal        = 70e3,                     # how far will offspring end up from their parents
#       path             = simulation_path,
#       overwrite        = TRUE
#     )
# }
#
# model
# Out:
# slendr 'model' object
# ---------------------
# populations: AFR, OOA, EHG, ANA, EUR, YAM
# geneflow events: [no geneflow]
# generation time: 30
# time direction: backward
# total running length: 52000 model time units
# model type: spatial
#   - number of spatial maps: 60
#   - resolution: 10000 distance units per pixel
#
# configuration files in: /maps/projects/racimolab/people/qxz396/spaceNNtime/data/europe

# %% [markdown]
# [<img src="arrow.png" width="100" style="float: left;">](#Home) &nbsp;
#
# &nbsp;
#
# <a name="Exp"></a>
# ### D. Explore the model
#
# The command below `explore()` would by default open a browser. However, I added an otpion (`launchbrowser`) so that this can be prevented and istead, a link is provided (`launchbrowser = FALSE`). We can connect to that link using an **ssh tunel**. To do that:
#
# 1. run `explore(model, launchbrowser = FALSE)` in R. You will obtain a similar output than the cell below.

# %% [raw]
# R[write to console]: Loading required package: shiny
#
# R[write to console]:
# Listening on http://127.0.0.1:7878

# %% [markdown]
# 2. The http link has been provided. We can create a ssh tunel to connect to it by running the follwing command in a terminal in our local computer.

# %% [raw]
# ssh -N -L 7878:localhost:7878 qxz396@racimocomp04fl

# %% [markdown]
# 3. Check that the ports (numbers surrounding the "localhost" and the last digits in the link) should be the same.
# 4. Pate `localhost:7878` in a web browser
# 5. The `explore()` command can't be stopped if it's run with the `launchbrowser = FALSE` option. So, consider if you want to restart the kernel before running that function.

# %%
# %%R
#
# #explore(model, launchbrowser = FALSE)
# Out:
# NULL

# %%
# %%R -w 800
# plot_grid(
#     plot_map(afr, ooa, ehg, eur, ana, yam),
#     plot_model(model) + ggplot2::theme(legend.position = "none"))

# %% [markdown]
# [<img src="arrow.png" width="100" style="float: left;">](#Home) &nbsp;
#
# &nbsp;
#
# <a name="Sam"></a>
# ### E. Sampling
#
# Through slendr, I'll schedule a uniform random sampling of indiviudals through time that will amount to 3,000 individuals. From this initial simulation, I'll downsample, alter the sampling strategy (exponentially random sampling) and other perturbations of the simulation to test the neural network in later steps of the pipeline.

# %%
# %%R
#
# set.seed(1234)
#
# pops_list  <- list(afr, ooa, ehg, eur, ana, yam)
#
# pop_timing <- data.frame(pop   = c("AFR", "OOA", "EHG", "EUR", "ANA", "YAM"),
#                          start = c(52000, 51000, 28000, 25000, 28000,  7000),
#                          end   = c(    0, 25000,  6000,     0,  4000,  2500),
#                          index = c(    1,     2,     3,     4,     5,     6)) %>%
#                         dplyr::filter(pop != "AFR")
#
# if(! file.exists(paste(simulation_path, "/input_slim_sampling.tsv", sep = ""))){
#     print("File does not exist, creating sampling dataframe")
#     samples    <- sampling_uniform_intime(15000, pop_timing, pops_list)
#     write.table(samples, file = paste(simulation_path, "/input_slim_sampling.tsv", sep = ""), quote=FALSE, col.names=TRUE)
# }else{
#     print("File exist, reading...")
#     samples    <- read.table(paste(simulation_path, "/input_slim_sampling.tsv", sep = ""), header = T)
# }
# head(samples)
# Out:
# [1] "File exist, reading..."
#    time pop n y_orig x_orig  y  x
# 1  6242 YAM 1     NA     NA NA NA
# 2 31268 OOA 1     NA     NA NA NA
# 3 43976 OOA 1     NA     NA NA NA
# 4   980 EUR 1     NA     NA NA NA
# 5 34137 OOA 1     NA     NA NA NA
# 6 35526 OOA 1     NA     NA NA NA

# %%
# %%R
#
# samples %>% dplyr::summarize(sum(n))
# Out:
#   sum(n)
# 1  15000

# %%
# %%R
#
# samples %>% summary()
# Out:
#       time           pop                  n        y_orig         x_orig
#  Min.   :  502   Length:13639       Min.   :1.0   Mode:logical   Mode:logical
#  1st Qu.:12884   Class :character   1st Qu.:1.0   NA's:13639     NA's:13639
#  Median :24883   Mode  :character   Median :1.0
#  Mean   :25308                      Mean   :1.1
#  3rd Qu.:37718                      3rd Qu.:1.0
#  Max.   :50959                      Max.   :4.0
#     y              x
#  Mode:logical   Mode:logical
#  NA's:13639     NA's:13639

# %%
# %%R
#
# gg_color_hue <- function(n) {
#   hues = seq(15, 375, length = n + 1)
#   hcl(h = hues, l = 65, c = 100)[1:n]
# }
#
# colors = gg_color_hue(6)
# col_pop = c("AFR" = colors[1], "OOA" = colors[2], "EHG" = colors[3],
#             "ANA" = colors[4], "EUR" = colors[5], "YAM" = colors[6])

# %%
# %%R -w 800
#
# plot_grid(
#
#     samples_subset %>%
#         tidyr::uncount(n) %>%
#         dplyr::mutate(pop = factor(pop, levels = c("OOA", "EHG", "ANA", "EUR", "YAM"))) %>%
#         ggplot() +
#         geom_jitter(aes(x = pop, y = time/1000, color = pop)) +
#         scale_color_manual(values=col_pop) +
#         xlab("") +
#         ylab("Time (years x1000)") +
#         theme_light() +
#         theme(legend.position = "none"),
#
#     samples_subset %>%
#         tidyr::uncount(n) %>%
#         ggplot() +
#         geom_histogram(aes(y = time, fill = pop), bins = 30) +
#         theme_light() +
#         scale_fill_manual(values=col_pop) +
#         theme(axis.ticks.y = element_blank(), axis.title.y = element_blank(), axis.text.y= element_blank(), legend.position = "none"),
#
#     rel_widths= c(2, 1))

# %%
# %%R
#
# #ggsave("../sandbox/europe/plots/samp.pdf", width = 4, height = 3, dpi = 300, units = "in")
# Out:
# NULL

# %% [markdown]
# [<img src="arrow.png" width="100" style="float: left;">](#Home) &nbsp;
#
# &nbsp;
#
# <a name="Sim"></a>
# ### F. Simulate

# %%
# %%R
#
# if(file.exists(paste(simulation_path, "/output_slim.trees", sep = ""))){
#     print("Simulations already done!")
# }else{
#     slim(
#       model,
#       sequence_length    = 1e6,
#       recombination_rate = 1e-8, # simulate only a single locus
#       sampling           = samples,
#       verbose            = TRUE,
#       #ts_recording = TRUE,
#       save_locations     = TRUE, # save the location of everyone who ever lived
#       save_sampling      = TRUE,
#       method             = "batch", # change to "gui" to execute the model in SLiMgui
#       random_seed        = 1234
#     )
# }
# Out:
# --------------------------------------------------
# SLiM command to be executed:
#
# slim  \
#     -d SEED=1234  \
#     -d 'SAMPLES="/maps/projects/racimolab/people/qxz396/spaceNNtime/data/europe/output_slim_sampling.tsv"' \
#     -d 'MODEL="/maps/projects/racimolab/people/qxz396/spaceNNtime/data/europe"' \
#     -d 'OUTPUT="/maps/projects/racimolab/people/qxz396/spaceNNtime/data/europe/output"' \
#     -d SPATIAL=T \
#     -d SEQUENCE_LENGTH=1000000 \
#     -d RECOMB_RATE=1e-08 \
#     -d BURNIN_LENGTH=0 \
#     -d SIMULATION_LENGTH=1733 \
#     -d SAVE_LOCATIONS=T \
#     -d COALESCENT_ONLY=T \
#     -d MAX_ATTEMPTS=1 \
#     /maps/projects/racimolab/people/qxz396/spaceNNtime/data/europe/script.slim
# --------------------------------------------------
#
# // Initial random seed:
# 40358992303293
#
# // RunInitializeCallbacks():
# SEED: 1234
# initializeSLiMOptions(keepPedigrees = T, dimensionality = 'xy');
# initializeInteractionType(0, "xy", reciprocal=T, maxDistance=13);
# initializeInteractionType(1, "xy", reciprocal=T, maxDistance=10);
# initializeInteractionType(2, "xy", reciprocal=T, maxDistance=13);
# initializeInteractionType(3, "xy", reciprocal=T, maxDistance=10);
# initializeInteractionType(4, "xy", reciprocal=T, maxDistance=13);
# initializeInteractionType(5, "xy", reciprocal=T, maxDistance=10);
# initializeInteractionType(6, "xy", reciprocal=T, maxDistance=13);
# initializeInteractionType(7, "xy", reciprocal=T, maxDistance=10);
# initializeInteractionType(8, "xy", reciprocal=T, maxDistance=13);
# initializeInteractionType(9, "xy", reciprocal=T, maxDistance=10);
# initializeInteractionType(10, "xy", reciprocal=T, maxDistance=13);
# initializeInteractionType(11, "xy", reciprocal=T, maxDistance=10);
# initializeTreeSeq();
# initializeMutationType(0, 0.5, "f", 0);
# initializeGenomicElementType(1, m0, 1);
# initializeGenomicElement(g1, 0, 999999);
# initializeMutationRate(0);
# initializeRecombinationRate(1e-08);
#
# // Starting run at generation <start>:
# 1
#
# Generation 1: starting the simulation
# Generation 1: creating AFR(p0)
# Generation 1: updating map for AFR(p0)
# Generation 1: distributing individuals of AFR(p0)
# Generation 34: split of OOA(p1) from AFR(p0)
# Generation 34: updating map for OOA(p1)
# Generation 34: distributing individuals of OOA(p1)
# Generation 36: sampling 1 individuals of OOA(p1)
# Generation 36: sampling 2 individuals of OOA(p1)
# Generation 36: sampling 2 individuals of OOA(p1)
# Generation 36: sampling 1 individuals of OOA(p1)
# Generation 36: sampling 1 individuals of OOA(p1)
# Generation 36: sampling 1 individuals of OOA(p1)
# Generation 36: sampling 1 individuals of OOA(p1)
# Generation 37: sampling 2 individuals of OOA(p1)
# Generation 37: sampling 2 individuals of OOA(p1)
# Generation 37: sampling 1 individuals of OOA(p1)
# Generation 37: sampling 1 individuals of OOA(p1)
# Generation 37: sampling 1 individuals of OOA(p1)
# Generation 37: sampling 1 individuals of OOA(p1)
# Generation 38: sampling 1 individuals of OOA(p1)
# Generation 38: sampling 1 individuals of OOA(p1)
# Generation 38: sampling 1 individuals of OOA(p1)
# Generation 38: sampling 1 individuals of OOA(p1)
# Generation 38: sampling 1 individuals of OOA(p1)
# Generation 38: sampling 2 individuals of OOA(p1)
# Generation 38: sampling 1 individuals of OOA(p1)
# Generation 38: sampling 1 individuals of OOA(p1)
# Generation 38: sampling 1 individuals of OOA(p1)
# Generation 39: sampling 1 individuals of OOA(p1)
# Generation 39: sampling 1 individuals of OOA(p1)
# Generation 39: sampling 2 individuals of OOA(p1)
# Generation 39: sampling 1 individuals of OOA(p1)
# Generation 39: sampling 2 individuals of OOA(p1)
# Generation 39: sampling 1 individuals of OOA(p1)
# Generation 40: sampling 1 individuals of OOA(p1)
# Generation 40: sampling 2 individuals of OOA(p1)
# Generation 40: sampling 1 individuals of OOA(p1)
# Generation 40: sampling 1 individuals of OOA(p1)
# Generation 40: sampling 1 individuals of OOA(p1)
# Generation 40: sampling 1 individuals of OOA(p1)
# Generation 40: sampling 1 individuals of OOA(p1)
# Generation 40: sampling 1 individuals of OOA(p1)
# Generation 40: sampling 1 individuals of OOA(p1)
# Generation 41: sampling 1 individuals of OOA(p1)
# Generation 41: sampling 1 individuals of OOA(p1)
# Generation 41: sampling 1 individuals of OOA(p1)
# Generation 41: sampling 2 individuals of OOA(p1)
# Generation 41: sampling 1 individuals of OOA(p1)
# Generation 41: sampling 1 individuals of OOA(p1)
# Generation 41: sampling 1 individuals of OOA(p1)
# Generation 41: sampling 1 individuals of OOA(p1)
# Generation 41: sampling 1 individuals of OOA(p1)
# Generation 42: sampling 1 individuals of OOA(p1)
# Generation 42: sampling 1 individuals of OOA(p1)
# Generation 42: sampling 1 individuals of OOA(p1)
# Generation 42: sampling 1 individuals of OOA(p1)
# Generation 42: sampling 1 individuals of OOA(p1)
# Generation 42: sampling 1 individuals of OOA(p1)
# Generation 43: sampling 1 individuals of OOA(p1)
# Generation 43: sampling 2 individuals of OOA(p1)
# Generation 43: sampling 2 individuals of OOA(p1)
# Generation 44: sampling 1 individuals of OOA(p1)
# Generation 44: sampling 1 individuals of OOA(p1)
# Generation 44: sampling 2 individuals of OOA(p1)
# Generation 44: sampling 1 individuals of OOA(p1)
# Generation 44: sampling 1 individuals of OOA(p1)
# Generation 44: sampling 1 individuals of OOA(p1)
# Generation 45: sampling 1 individuals of OOA(p1)
# Generation 45: sampling 1 individuals of OOA(p1)
# Generation 45: sampling 2 individuals of OOA(p1)
# Generation 45: sampling 1 individuals of OOA(p1)
# Generation 45: sampling 1 individuals of OOA(p1)
# Generation 45: sampling 1 individuals of OOA(p1)
# Generation 46: sampling 1 individuals of OOA(p1)
# Generation 46: sampling 1 individuals of OOA(p1)
# Generation 46: sampling 1 individuals of OOA(p1)
# Generation 46: sampling 1 individuals of OOA(p1)
# Generation 46: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 47: sampling 1 individuals of OOA(p1)
# Generation 48: sampling 1 individuals of OOA(p1)
# Generation 48: sampling 1 individuals of OOA(p1)
# Generation 48: sampling 1 individuals of OOA(p1)
# Generation 48: sampling 1 individuals of OOA(p1)
# Generation 48: sampling 2 individuals of OOA(p1)
# Generation 48: sampling 1 individuals of OOA(p1)
# Generation 49: sampling 1 individuals of OOA(p1)
# Generation 49: sampling 1 individuals of OOA(p1)
# Generation 49: sampling 2 individuals of OOA(p1)
# Generation 49: sampling 1 individuals of OOA(p1)
# Generation 49: sampling 1 individuals of OOA(p1)
# Generation 49: sampling 1 individuals of OOA(p1)
# Generation 49: sampling 1 individuals of OOA(p1)
# Generation 49: sampling 2 individuals of OOA(p1)
# Generation 49: sampling 1 individuals of OOA(p1)
# Generation 50: sampling 1 individuals of OOA(p1)
# Generation 50: sampling 1 individuals of OOA(p1)
# Generation 50: sampling 2 individuals of OOA(p1)
# Generation 50: sampling 1 individuals of OOA(p1)
# Generation 50: sampling 1 individuals of OOA(p1)
# Generation 50: sampling 1 individuals of OOA(p1)
# Generation 50: sampling 1 individuals of OOA(p1)
# Generation 50: sampling 1 individuals of OOA(p1)
# Generation 50: sampling 1 individuals of OOA(p1)
# Generation 51: sampling 2 individuals of OOA(p1)
# Generation 51: sampling 1 individuals of OOA(p1)
# Generation 51: sampling 1 individuals of OOA(p1)
# Generation 51: sampling 1 individuals of OOA(p1)
# Generation 51: sampling 1 individuals of OOA(p1)
# Generation 51: sampling 1 individuals of OOA(p1)
# Generation 51: sampling 1 individuals of OOA(p1)
# Generation 51: sampling 1 individuals of OOA(p1)
# Generation 52: sampling 1 individuals of OOA(p1)
# Generation 52: sampling 1 individuals of OOA(p1)
# Generation 52: sampling 2 individuals of OOA(p1)
# Generation 52: sampling 2 individuals of OOA(p1)
# Generation 52: sampling 1 individuals of OOA(p1)
# Generation 52: sampling 3 individuals of OOA(p1)
# Generation 52: sampling 1 individuals of OOA(p1)
# Generation 53: sampling 1 individuals of OOA(p1)
# Generation 54: sampling 1 individuals of OOA(p1)
# Generation 54: sampling 1 individuals of OOA(p1)
# Generation 54: sampling 1 individuals of OOA(p1)
# Generation 54: sampling 2 individuals of OOA(p1)
# Generation 54: sampling 1 individuals of OOA(p1)
# Generation 54: sampling 1 individuals of OOA(p1)
# Generation 54: sampling 1 individuals of OOA(p1)
# Generation 54: sampling 1 individuals of OOA(p1)
# Generation 54: sampling 1 individuals of OOA(p1)
# Generation 54: sampling 1 individuals of OOA(p1)
# Generation 54: sampling 2 individuals of OOA(p1)
# Generation 54: sampling 1 individuals of OOA(p1)
# Generation 55: sampling 1 individuals of OOA(p1)
# Generation 55: sampling 1 individuals of OOA(p1)
# Generation 55: sampling 1 individuals of OOA(p1)
# Generation 55: sampling 1 individuals of OOA(p1)
# Generation 55: sampling 1 individuals of OOA(p1)
# Generation 55: sampling 1 individuals of OOA(p1)
# Generation 55: sampling 1 individuals of OOA(p1)
# Generation 55: sampling 1 individuals of OOA(p1)
# Generation 55: sampling 1 individuals of OOA(p1)
# Generation 55: sampling 2 individuals of OOA(p1)
# Generation 56: sampling 1 individuals of OOA(p1)
# Generation 56: sampling 1 individuals of OOA(p1)
# Generation 56: sampling 1 individuals of OOA(p1)
# Generation 56: sampling 1 individuals of OOA(p1)
# Generation 56: sampling 1 individuals of OOA(p1)
# Generation 56: sampling 1 individuals of OOA(p1)
# Generation 57: sampling 1 individuals of OOA(p1)
# Generation 57: sampling 1 individuals of OOA(p1)
# Generation 57: sampling 1 individuals of OOA(p1)
# Generation 57: sampling 1 individuals of OOA(p1)
# Generation 57: sampling 1 individuals of OOA(p1)
# Generation 57: sampling 1 individuals of OOA(p1)
# Generation 57: sampling 2 individuals of OOA(p1)
# Generation 57: sampling 1 individuals of OOA(p1)
# Generation 57: sampling 1 individuals of OOA(p1)
# Generation 58: sampling 1 individuals of OOA(p1)
# Generation 58: sampling 1 individuals of OOA(p1)
# Generation 58: sampling 1 individuals of OOA(p1)
# Generation 58: sampling 1 individuals of OOA(p1)
# Generation 59: sampling 1 individuals of OOA(p1)
# Generation 59: sampling 1 individuals of OOA(p1)
# Generation 59: sampling 2 individuals of OOA(p1)
# Generation 59: sampling 1 individuals of OOA(p1)
# Generation 59: sampling 1 individuals of OOA(p1)
# Generation 59: sampling 2 individuals of OOA(p1)
# Generation 59: sampling 2 individuals of OOA(p1)
# Generation 60: sampling 1 individuals of OOA(p1)
# Generation 60: sampling 1 individuals of OOA(p1)
# Generation 60: sampling 1 individuals of OOA(p1)
# Generation 60: sampling 1 individuals of OOA(p1)
# Generation 60: sampling 2 individuals of OOA(p1)
# Generation 60: sampling 1 individuals of OOA(p1)
# Generation 61: sampling 2 individuals of OOA(p1)
# Generation 61: sampling 1 individuals of OOA(p1)
# Generation 61: sampling 1 individuals of OOA(p1)
# Generation 62: sampling 1 individuals of OOA(p1)
# Generation 62: sampling 1 individuals of OOA(p1)
# Generation 62: sampling 1 individuals of OOA(p1)
# Generation 62: sampling 2 individuals of OOA(p1)
# Generation 62: sampling 1 individuals of OOA(p1)
# Generation 62: sampling 1 individuals of OOA(p1)
# Generation 62: sampling 1 individuals of OOA(p1)
# Generation 62: sampling 1 individuals of OOA(p1)
# Generation 63: sampling 2 individuals of OOA(p1)
# Generation 63: sampling 2 individuals of OOA(p1)
# Generation 63: sampling 2 individuals of OOA(p1)
# Generation 63: sampling 1 individuals of OOA(p1)
# Generation 63: sampling 1 individuals of OOA(p1)
# Generation 63: sampling 2 individuals of OOA(p1)
# Generation 63: sampling 1 individuals of OOA(p1)
# Generation 63: sampling 1 individuals of OOA(p1)
# Generation 63: sampling 1 individuals of OOA(p1)
# Generation 63: sampling 1 individuals of OOA(p1)
# Generation 64: sampling 1 individuals of OOA(p1)
# Generation 64: sampling 1 individuals of OOA(p1)
# Generation 64: sampling 1 individuals of OOA(p1)
# Generation 64: sampling 1 individuals of OOA(p1)
# Generation 64: sampling 2 individuals of OOA(p1)
# Generation 64: sampling 1 individuals of OOA(p1)
# Generation 65: sampling 1 individuals of OOA(p1)
# Generation 65: sampling 1 individuals of OOA(p1)
# Generation 65: sampling 1 individuals of OOA(p1)
# Generation 65: sampling 3 individuals of OOA(p1)
# Generation 65: sampling 1 individuals of OOA(p1)
# Generation 65: sampling 1 individuals of OOA(p1)
# Generation 65: sampling 2 individuals of OOA(p1)
# Generation 66: sampling 1 individuals of OOA(p1)
# Generation 66: sampling 1 individuals of OOA(p1)
# Generation 66: sampling 1 individuals of OOA(p1)
# Generation 66: sampling 1 individuals of OOA(p1)
# Generation 66: sampling 1 individuals of OOA(p1)
# Generation 66: sampling 1 individuals of OOA(p1)
# Generation 66: sampling 2 individuals of OOA(p1)
# Generation 66: sampling 1 individuals of OOA(p1)
# Generation 66: sampling 1 individuals of OOA(p1)
# Generation 67: sampling 1 individuals of OOA(p1)
# Generation 67: sampling 1 individuals of OOA(p1)
# Generation 67: sampling 1 individuals of OOA(p1)
# Generation 67: sampling 1 individuals of OOA(p1)
# Generation 67: sampling 1 individuals of OOA(p1)
# Generation 67: sampling 1 individuals of OOA(p1)
# Generation 67: sampling 1 individuals of OOA(p1)
# Generation 67: sampling 1 individuals of OOA(p1)
# Generation 68: sampling 3 individuals of OOA(p1)
# Generation 68: sampling 3 individuals of OOA(p1)
# Generation 68: sampling 3 individuals of OOA(p1)
# Generation 68: sampling 1 individuals of OOA(p1)
# Generation 68: sampling 1 individuals of OOA(p1)
# Generation 68: sampling 1 individuals of OOA(p1)
# Generation 68: sampling 1 individuals of OOA(p1)
# Generation 68: sampling 1 individuals of OOA(p1)
# Generation 68: sampling 2 individuals of OOA(p1)
# Generation 68: sampling 1 individuals of OOA(p1)
# Generation 68: sampling 1 individuals of OOA(p1)
# Generation 68: sampling 1 individuals of OOA(p1)
# Generation 68: updating map for OOA(p1)
# Generation 69: sampling 1 individuals of OOA(p1)
# Generation 69: sampling 1 individuals of OOA(p1)
# Generation 69: sampling 1 individuals of OOA(p1)
# Generation 69: sampling 1 individuals of OOA(p1)
# Generation 69: sampling 1 individuals of OOA(p1)
# Generation 69: sampling 1 individuals of OOA(p1)
# Generation 69: sampling 1 individuals of OOA(p1)
# Generation 70: sampling 1 individuals of OOA(p1)
# Generation 70: sampling 2 individuals of OOA(p1)
# Generation 70: sampling 1 individuals of OOA(p1)
# Generation 70: sampling 1 individuals of OOA(p1)
# Generation 70: sampling 1 individuals of OOA(p1)
# Generation 70: sampling 1 individuals of OOA(p1)
# Generation 70: sampling 1 individuals of OOA(p1)
# Generation 70: sampling 1 individuals of OOA(p1)
# Generation 70: sampling 1 individuals of OOA(p1)
# Generation 70: sampling 1 individuals of OOA(p1)
# Generation 70: sampling 1 individuals of OOA(p1)
# Generation 71: sampling 2 individuals of OOA(p1)
# Generation 71: sampling 2 individuals of OOA(p1)
# Generation 71: sampling 2 individuals of OOA(p1)
# Generation 71: sampling 1 individuals of OOA(p1)
# Generation 71: sampling 1 individuals of OOA(p1)
# Generation 71: sampling 1 individuals of OOA(p1)
# Generation 71: sampling 1 individuals of OOA(p1)
# Generation 71: sampling 1 individuals of OOA(p1)
# Generation 72: sampling 1 individuals of OOA(p1)
# Generation 72: sampling 1 individuals of OOA(p1)
# Generation 72: sampling 1 individuals of OOA(p1)
# Generation 72: sampling 3 individuals of OOA(p1)
# Generation 72: sampling 1 individuals of OOA(p1)
# Generation 72: sampling 1 individuals of OOA(p1)
# Generation 73: sampling 1 individuals of OOA(p1)
# Generation 73: sampling 2 individuals of OOA(p1)
# Generation 73: sampling 1 individuals of OOA(p1)
# Generation 73: sampling 1 individuals of OOA(p1)
# Generation 73: sampling 1 individuals of OOA(p1)
# Generation 73: sampling 1 individuals of OOA(p1)
# Generation 73: sampling 1 individuals of OOA(p1)
# Generation 74: sampling 1 individuals of OOA(p1)
# Generation 74: sampling 2 individuals of OOA(p1)
# Generation 74: sampling 1 individuals of OOA(p1)
# Generation 74: sampling 1 individuals of OOA(p1)
# Generation 74: sampling 1 individuals of OOA(p1)
# Generation 74: sampling 1 individuals of OOA(p1)
# Generation 74: sampling 1 individuals of OOA(p1)
# Generation 74: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 2 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 75: sampling 2 individuals of OOA(p1)
# Generation 75: sampling 1 individuals of OOA(p1)
# Generation 76: sampling 1 individuals of OOA(p1)
# Generation 76: sampling 2 individuals of OOA(p1)
# Generation 76: sampling 1 individuals of OOA(p1)
# Generation 76: sampling 1 individuals of OOA(p1)
# Generation 76: sampling 3 individuals of OOA(p1)
# Generation 76: sampling 1 individuals of OOA(p1)
# Generation 77: sampling 1 individuals of OOA(p1)
# Generation 77: sampling 1 individuals of OOA(p1)
# Generation 77: sampling 2 individuals of OOA(p1)
# Generation 77: sampling 1 individuals of OOA(p1)
# Generation 77: sampling 1 individuals of OOA(p1)
# Generation 78: sampling 1 individuals of OOA(p1)
# Generation 78: sampling 2 individuals of OOA(p1)
# Generation 78: sampling 1 individuals of OOA(p1)
# Generation 78: sampling 1 individuals of OOA(p1)
# Generation 78: sampling 1 individuals of OOA(p1)
# Generation 78: sampling 1 individuals of OOA(p1)
# Generation 78: sampling 1 individuals of OOA(p1)
# Generation 78: sampling 1 individuals of OOA(p1)
# Generation 79: sampling 1 individuals of OOA(p1)
# Generation 79: sampling 1 individuals of OOA(p1)
# Generation 79: sampling 1 individuals of OOA(p1)
# Generation 79: sampling 2 individuals of OOA(p1)
# Generation 79: sampling 1 individuals of OOA(p1)
# Generation 79: sampling 1 individuals of OOA(p1)
# Generation 79: sampling 2 individuals of OOA(p1)
# Generation 79: sampling 1 individuals of OOA(p1)
# Generation 79: sampling 1 individuals of OOA(p1)
# Generation 79: sampling 1 individuals of OOA(p1)
# Generation 80: sampling 1 individuals of OOA(p1)
# Generation 80: sampling 2 individuals of OOA(p1)
# Generation 81: sampling 2 individuals of OOA(p1)
# Generation 81: sampling 1 individuals of OOA(p1)
# Generation 81: sampling 1 individuals of OOA(p1)
# Generation 81: sampling 1 individuals of OOA(p1)
# Generation 81: sampling 2 individuals of OOA(p1)
# Generation 81: sampling 1 individuals of OOA(p1)
# Generation 81: sampling 1 individuals of OOA(p1)
# Generation 82: sampling 1 individuals of OOA(p1)
# Generation 82: sampling 1 individuals of OOA(p1)
# Generation 82: sampling 1 individuals of OOA(p1)
# Generation 82: sampling 1 individuals of OOA(p1)
# Generation 82: sampling 1 individuals of OOA(p1)
# Generation 82: sampling 1 individuals of OOA(p1)
# Generation 82: sampling 1 individuals of OOA(p1)
# Generation 82: sampling 1 individuals of OOA(p1)
# Generation 83: sampling 1 individuals of OOA(p1)
# Generation 83: sampling 1 individuals of OOA(p1)
# Generation 83: sampling 1 individuals of OOA(p1)
# Generation 83: sampling 1 individuals of OOA(p1)
# Generation 83: sampling 1 individuals of OOA(p1)
# Generation 83: sampling 1 individuals of OOA(p1)
# Generation 83: updating map for OOA(p1)
# Generation 84: sampling 2 individuals of OOA(p1)
# Generation 84: sampling 1 individuals of OOA(p1)
# Generation 84: sampling 1 individuals of OOA(p1)
# Generation 84: sampling 3 individuals of OOA(p1)
# Generation 84: sampling 1 individuals of OOA(p1)
# Generation 84: sampling 1 individuals of OOA(p1)
# Generation 84: sampling 1 individuals of OOA(p1)
# Generation 84: sampling 1 individuals of OOA(p1)
# Generation 85: sampling 2 individuals of OOA(p1)
# Generation 85: sampling 1 individuals of OOA(p1)
# Generation 85: sampling 1 individuals of OOA(p1)
# Generation 85: sampling 1 individuals of OOA(p1)
# Generation 85: sampling 1 individuals of OOA(p1)
# Generation 85: sampling 2 individuals of OOA(p1)
# Generation 85: sampling 1 individuals of OOA(p1)
# Generation 85: sampling 1 individuals of OOA(p1)
# Generation 86: sampling 1 individuals of OOA(p1)
# Generation 86: sampling 1 individuals of OOA(p1)
# Generation 86: sampling 1 individuals of OOA(p1)
# Generation 86: sampling 1 individuals of OOA(p1)
# Generation 86: sampling 1 individuals of OOA(p1)
# Generation 86: sampling 1 individuals of OOA(p1)
# Generation 86: sampling 1 individuals of OOA(p1)
# Generation 86: sampling 1 individuals of OOA(p1)
# Generation 86: sampling 1 individuals of OOA(p1)
# Generation 86: sampling 1 individuals of OOA(p1)
# Generation 87: sampling 1 individuals of OOA(p1)
# Generation 87: sampling 2 individuals of OOA(p1)
# Generation 87: sampling 1 individuals of OOA(p1)
# Generation 87: sampling 1 individuals of OOA(p1)
# Generation 87: sampling 1 individuals of OOA(p1)
# Generation 87: sampling 1 individuals of OOA(p1)
# Generation 87: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 2 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 3 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 88: sampling 1 individuals of OOA(p1)
# Generation 89: sampling 1 individuals of OOA(p1)
# Generation 89: sampling 1 individuals of OOA(p1)
# Generation 89: sampling 1 individuals of OOA(p1)
# Generation 89: sampling 1 individuals of OOA(p1)
# Generation 89: sampling 1 individuals of OOA(p1)
# Generation 89: sampling 1 individuals of OOA(p1)
# Generation 89: sampling 2 individuals of OOA(p1)
# Generation 89: sampling 1 individuals of OOA(p1)
# Generation 90: sampling 1 individuals of OOA(p1)
# Generation 90: sampling 1 individuals of OOA(p1)
# Generation 90: sampling 1 individuals of OOA(p1)
# Generation 90: sampling 1 individuals of OOA(p1)
# Generation 90: sampling 1 individuals of OOA(p1)
# Generation 90: sampling 1 individuals of OOA(p1)
# Generation 90: sampling 1 individuals of OOA(p1)
# Generation 90: sampling 2 individuals of OOA(p1)
# Generation 90: sampling 1 individuals of OOA(p1)
# Generation 90: sampling 2 individuals of OOA(p1)
# Generation 90: sampling 1 individuals of OOA(p1)
# Generation 91: sampling 1 individuals of OOA(p1)
# Generation 91: sampling 1 individuals of OOA(p1)
# Generation 91: sampling 1 individuals of OOA(p1)
# Generation 91: sampling 1 individuals of OOA(p1)
# Generation 91: sampling 1 individuals of OOA(p1)
# Generation 91: sampling 2 individuals of OOA(p1)
# Generation 91: sampling 2 individuals of OOA(p1)
# Generation 91: sampling 2 individuals of OOA(p1)
# Generation 92: sampling 1 individuals of OOA(p1)
# Generation 92: sampling 1 individuals of OOA(p1)
# Generation 92: sampling 1 individuals of OOA(p1)
# Generation 92: sampling 1 individuals of OOA(p1)
# Generation 92: sampling 1 individuals of OOA(p1)
# Generation 92: sampling 1 individuals of OOA(p1)
# Generation 92: sampling 1 individuals of OOA(p1)
# Generation 92: sampling 2 individuals of OOA(p1)
# Generation 92: sampling 1 individuals of OOA(p1)
# Generation 93: sampling 1 individuals of OOA(p1)
# Generation 93: sampling 1 individuals of OOA(p1)
# Generation 93: sampling 1 individuals of OOA(p1)
# Generation 93: sampling 1 individuals of OOA(p1)
# Generation 93: sampling 1 individuals of OOA(p1)
# Generation 93: sampling 1 individuals of OOA(p1)
# Generation 93: sampling 1 individuals of OOA(p1)
# Generation 93: sampling 1 individuals of OOA(p1)
# Generation 94: sampling 1 individuals of OOA(p1)
# Generation 94: sampling 1 individuals of OOA(p1)
# Generation 94: sampling 1 individuals of OOA(p1)
# Generation 94: sampling 1 individuals of OOA(p1)
# Generation 94: sampling 1 individuals of OOA(p1)
# Generation 94: sampling 1 individuals of OOA(p1)
# Generation 94: sampling 2 individuals of OOA(p1)
# Generation 94: sampling 1 individuals of OOA(p1)
# Generation 95: sampling 1 individuals of OOA(p1)
# Generation 95: sampling 1 individuals of OOA(p1)
# Generation 95: sampling 1 individuals of OOA(p1)
# Generation 95: sampling 1 individuals of OOA(p1)
# Generation 95: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 1 individuals of OOA(p1)
# Generation 96: sampling 2 individuals of OOA(p1)
# Generation 97: sampling 1 individuals of OOA(p1)
# Generation 97: sampling 2 individuals of OOA(p1)
# Generation 97: sampling 1 individuals of OOA(p1)
# Generation 97: sampling 1 individuals of OOA(p1)
# Generation 97: sampling 1 individuals of OOA(p1)
# Generation 97: sampling 1 individuals of OOA(p1)
# Generation 98: sampling 1 individuals of OOA(p1)
# Generation 98: sampling 1 individuals of OOA(p1)
# Generation 98: sampling 1 individuals of OOA(p1)
# Generation 98: sampling 1 individuals of OOA(p1)
# Generation 98: sampling 1 individuals of OOA(p1)
# Generation 98: sampling 1 individuals of OOA(p1)
# Generation 98: sampling 1 individuals of OOA(p1)
# Generation 98: sampling 1 individuals of OOA(p1)
# Generation 98: sampling 1 individuals of OOA(p1)
# Generation 98: sampling 1 individuals of OOA(p1)
# Generation 98: updating map for OOA(p1)
# Generation 99: sampling 1 individuals of OOA(p1)
# Generation 99: sampling 1 individuals of OOA(p1)
# Generation 99: sampling 1 individuals of OOA(p1)
# Generation 99: sampling 1 individuals of OOA(p1)
# Generation 99: sampling 1 individuals of OOA(p1)
# Generation 100: sampling 1 individuals of OOA(p1)
# Generation 100: sampling 1 individuals of OOA(p1)
# Generation 100: sampling 1 individuals of OOA(p1)
# Generation 100: sampling 2 individuals of OOA(p1)
# Generation 100: sampling 1 individuals of OOA(p1)
# Generation 100: sampling 1 individuals of OOA(p1)
# Generation 100: sampling 1 individuals of OOA(p1)
# Generation 100: sampling 1 individuals of OOA(p1)
# Generation 101: sampling 1 individuals of OOA(p1)
# Generation 101: sampling 1 individuals of OOA(p1)
# Generation 101: sampling 1 individuals of OOA(p1)
# Generation 101: sampling 1 individuals of OOA(p1)
# Generation 101: sampling 1 individuals of OOA(p1)
# Generation 101: sampling 1 individuals of OOA(p1)
# Generation 101: sampling 1 individuals of OOA(p1)
# Generation 101: sampling 1 individuals of OOA(p1)
# Generation 101: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 102: sampling 1 individuals of OOA(p1)
# Generation 103: sampling 1 individuals of OOA(p1)
# Generation 103: sampling 1 individuals of OOA(p1)
# Generation 103: sampling 1 individuals of OOA(p1)
# Generation 103: sampling 2 individuals of OOA(p1)
# Generation 103: sampling 1 individuals of OOA(p1)
# Generation 103: sampling 2 individuals of OOA(p1)
# Generation 103: sampling 1 individuals of OOA(p1)
# Generation 104: sampling 1 individuals of OOA(p1)
# Generation 104: sampling 1 individuals of OOA(p1)
# Generation 104: sampling 1 individuals of OOA(p1)
# Generation 104: sampling 1 individuals of OOA(p1)
# Generation 105: sampling 2 individuals of OOA(p1)
# Generation 105: sampling 1 individuals of OOA(p1)
# Generation 105: sampling 2 individuals of OOA(p1)
# Generation 105: sampling 1 individuals of OOA(p1)
# Generation 105: sampling 1 individuals of OOA(p1)
# Generation 105: sampling 1 individuals of OOA(p1)
# Generation 105: sampling 1 individuals of OOA(p1)
# Generation 105: sampling 1 individuals of OOA(p1)
# Generation 106: sampling 1 individuals of OOA(p1)
# Generation 106: sampling 1 individuals of OOA(p1)
# Generation 106: sampling 1 individuals of OOA(p1)
# Generation 106: sampling 1 individuals of OOA(p1)
# Generation 106: sampling 2 individuals of OOA(p1)
# Generation 106: sampling 2 individuals of OOA(p1)
# Generation 106: sampling 1 individuals of OOA(p1)
# Generation 107: sampling 1 individuals of OOA(p1)
# Generation 107: sampling 1 individuals of OOA(p1)
# Generation 107: sampling 1 individuals of OOA(p1)
# Generation 107: sampling 1 individuals of OOA(p1)
# Generation 107: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 2 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 2 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 108: sampling 1 individuals of OOA(p1)
# Generation 109: sampling 1 individuals of OOA(p1)
# Generation 109: sampling 1 individuals of OOA(p1)
# Generation 109: sampling 2 individuals of OOA(p1)
# Generation 109: sampling 1 individuals of OOA(p1)
# Generation 110: sampling 1 individuals of OOA(p1)
# Generation 110: sampling 1 individuals of OOA(p1)
# Generation 110: sampling 1 individuals of OOA(p1)
# Generation 110: sampling 1 individuals of OOA(p1)
# Generation 110: sampling 1 individuals of OOA(p1)
# Generation 110: sampling 1 individuals of OOA(p1)
# Generation 110: sampling 1 individuals of OOA(p1)
# Generation 110: sampling 1 individuals of OOA(p1)
# Generation 111: sampling 1 individuals of OOA(p1)
# Generation 111: sampling 1 individuals of OOA(p1)
# Generation 111: sampling 1 individuals of OOA(p1)
# Generation 111: sampling 2 individuals of OOA(p1)
# Generation 111: sampling 1 individuals of OOA(p1)
# Generation 111: sampling 3 individuals of OOA(p1)
# Generation 111: sampling 1 individuals of OOA(p1)
# Generation 112: sampling 1 individuals of OOA(p1)
# Generation 112: sampling 1 individuals of OOA(p1)
# Generation 112: sampling 2 individuals of OOA(p1)
# Generation 112: sampling 3 individuals of OOA(p1)
# Generation 113: sampling 1 individuals of OOA(p1)
# Generation 113: sampling 2 individuals of OOA(p1)
# Generation 113: sampling 1 individuals of OOA(p1)
# Generation 113: sampling 1 individuals of OOA(p1)
# Generation 113: sampling 1 individuals of OOA(p1)
# Generation 113: sampling 1 individuals of OOA(p1)
# Generation 113: updating map for OOA(p1)
# Generation 114: sampling 1 individuals of OOA(p1)
# Generation 114: sampling 1 individuals of OOA(p1)
# Generation 114: sampling 1 individuals of OOA(p1)
# Generation 114: sampling 1 individuals of OOA(p1)
# Generation 114: sampling 3 individuals of OOA(p1)
# Generation 114: sampling 1 individuals of OOA(p1)
# Generation 115: sampling 1 individuals of OOA(p1)
# Generation 115: sampling 1 individuals of OOA(p1)
# Generation 115: sampling 1 individuals of OOA(p1)
# Generation 115: sampling 1 individuals of OOA(p1)
# Generation 115: sampling 1 individuals of OOA(p1)
# Generation 116: sampling 1 individuals of OOA(p1)
# Generation 116: sampling 1 individuals of OOA(p1)
# Generation 116: sampling 1 individuals of OOA(p1)
# Generation 116: sampling 1 individuals of OOA(p1)
# Generation 116: sampling 1 individuals of OOA(p1)
# Generation 116: sampling 1 individuals of OOA(p1)
# Generation 117: sampling 1 individuals of OOA(p1)
# Generation 117: sampling 1 individuals of OOA(p1)
# Generation 117: sampling 1 individuals of OOA(p1)
# Generation 117: sampling 1 individuals of OOA(p1)
# Generation 117: sampling 1 individuals of OOA(p1)
# Generation 117: sampling 1 individuals of OOA(p1)
# Generation 118: sampling 1 individuals of OOA(p1)
# Generation 118: sampling 1 individuals of OOA(p1)
# Generation 118: sampling 2 individuals of OOA(p1)
# Generation 118: sampling 1 individuals of OOA(p1)
# Generation 118: sampling 2 individuals of OOA(p1)
# Generation 118: sampling 1 individuals of OOA(p1)
# Generation 118: sampling 2 individuals of OOA(p1)
# Generation 118: sampling 2 individuals of OOA(p1)
# Generation 118: sampling 1 individuals of OOA(p1)
# Generation 119: sampling 1 individuals of OOA(p1)
# Generation 119: sampling 1 individuals of OOA(p1)
# Generation 119: sampling 1 individuals of OOA(p1)
# Generation 120: sampling 1 individuals of OOA(p1)
# Generation 120: sampling 1 individuals of OOA(p1)
# Generation 120: sampling 2 individuals of OOA(p1)
# Generation 120: sampling 1 individuals of OOA(p1)
# Generation 120: sampling 1 individuals of OOA(p1)
# Generation 120: sampling 1 individuals of OOA(p1)
# Generation 121: sampling 1 individuals of OOA(p1)
# Generation 121: sampling 1 individuals of OOA(p1)
# Generation 121: sampling 1 individuals of OOA(p1)
# Generation 121: sampling 1 individuals of OOA(p1)
# Generation 121: sampling 1 individuals of OOA(p1)
# Generation 121: sampling 1 individuals of OOA(p1)
# Generation 121: sampling 1 individuals of OOA(p1)
# Generation 121: sampling 1 individuals of OOA(p1)
# Generation 121: sampling 1 individuals of OOA(p1)
# Generation 122: sampling 1 individuals of OOA(p1)
# Generation 122: sampling 2 individuals of OOA(p1)
# Generation 122: sampling 1 individuals of OOA(p1)
# Generation 122: sampling 1 individuals of OOA(p1)
# Generation 122: sampling 1 individuals of OOA(p1)
# Generation 122: sampling 2 individuals of OOA(p1)
# Generation 122: sampling 1 individuals of OOA(p1)
# Generation 122: sampling 2 individuals of OOA(p1)
# Generation 122: sampling 1 individuals of OOA(p1)
# Generation 122: sampling 1 individuals of OOA(p1)
# Generation 122: sampling 1 individuals of OOA(p1)
# Generation 123: sampling 2 individuals of OOA(p1)
# Generation 123: sampling 1 individuals of OOA(p1)
# Generation 123: sampling 1 individuals of OOA(p1)
# Generation 123: sampling 1 individuals of OOA(p1)
# Generation 123: sampling 1 individuals of OOA(p1)
# Generation 123: sampling 1 individuals of OOA(p1)
# Generation 123: sampling 1 individuals of OOA(p1)
# Generation 123: sampling 1 individuals of OOA(p1)
# Generation 123: sampling 2 individuals of OOA(p1)
# Generation 123: sampling 1 individuals of OOA(p1)
# Generation 123: sampling 1 individuals of OOA(p1)
# Generation 123: sampling 1 individuals of OOA(p1)
# Generation 124: sampling 1 individuals of OOA(p1)
# Generation 124: sampling 1 individuals of OOA(p1)
# Generation 124: sampling 1 individuals of OOA(p1)
# Generation 124: sampling 1 individuals of OOA(p1)
# Generation 124: sampling 1 individuals of OOA(p1)
# Generation 124: sampling 3 individuals of OOA(p1)
# Generation 125: sampling 1 individuals of OOA(p1)
# Generation 125: sampling 1 individuals of OOA(p1)
# Generation 125: sampling 1 individuals of OOA(p1)
# Generation 125: sampling 2 individuals of OOA(p1)
# Generation 125: sampling 1 individuals of OOA(p1)
# Generation 125: sampling 2 individuals of OOA(p1)
# Generation 125: sampling 1 individuals of OOA(p1)
# Generation 126: sampling 1 individuals of OOA(p1)
# Generation 126: sampling 2 individuals of OOA(p1)
# Generation 126: sampling 1 individuals of OOA(p1)
# Generation 126: sampling 1 individuals of OOA(p1)
# Generation 126: sampling 1 individuals of OOA(p1)
# Generation 126: sampling 1 individuals of OOA(p1)
# Generation 126: sampling 1 individuals of OOA(p1)
# Generation 127: sampling 1 individuals of OOA(p1)
# Generation 127: sampling 1 individuals of OOA(p1)
# Generation 127: sampling 1 individuals of OOA(p1)
# Generation 127: sampling 2 individuals of OOA(p1)
# Generation 127: sampling 1 individuals of OOA(p1)
# Generation 127: sampling 1 individuals of OOA(p1)
# Generation 127: sampling 2 individuals of OOA(p1)
# Generation 128: sampling 1 individuals of OOA(p1)
# Generation 128: sampling 1 individuals of OOA(p1)
# Generation 128: sampling 1 individuals of OOA(p1)
# Generation 128: sampling 1 individuals of OOA(p1)
# Generation 128: sampling 1 individuals of OOA(p1)
# Generation 128: sampling 1 individuals of OOA(p1)
# Generation 128: sampling 1 individuals of OOA(p1)
# Generation 128: sampling 1 individuals of OOA(p1)
# Generation 128: sampling 1 individuals of OOA(p1)
# Generation 128: sampling 1 individuals of OOA(p1)
# Generation 128: updating map for OOA(p1)
# Generation 129: sampling 1 individuals of OOA(p1)
# Generation 129: sampling 1 individuals of OOA(p1)
# Generation 129: sampling 1 individuals of OOA(p1)
# Generation 129: sampling 1 individuals of OOA(p1)
# Generation 129: sampling 1 individuals of OOA(p1)
# Generation 129: sampling 1 individuals of OOA(p1)
# Generation 130: sampling 1 individuals of OOA(p1)
# Generation 130: sampling 1 individuals of OOA(p1)
# Generation 130: sampling 1 individuals of OOA(p1)
# Generation 130: sampling 2 individuals of OOA(p1)
# Generation 130: sampling 1 individuals of OOA(p1)
# Generation 130: sampling 1 individuals of OOA(p1)
# Generation 130: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 131: sampling 2 individuals of OOA(p1)
# Generation 131: sampling 1 individuals of OOA(p1)
# Generation 132: sampling 1 individuals of OOA(p1)
# Generation 132: sampling 1 individuals of OOA(p1)
# Generation 132: sampling 1 individuals of OOA(p1)
# Generation 132: sampling 1 individuals of OOA(p1)
# Generation 132: sampling 2 individuals of OOA(p1)
# Generation 132: sampling 1 individuals of OOA(p1)
# Generation 132: sampling 2 individuals of OOA(p1)
# Generation 132: sampling 1 individuals of OOA(p1)
# Generation 132: sampling 2 individuals of OOA(p1)
# Generation 132: sampling 1 individuals of OOA(p1)
# Generation 132: sampling 1 individuals of OOA(p1)
# Generation 133: sampling 1 individuals of OOA(p1)
# Generation 133: sampling 1 individuals of OOA(p1)
# Generation 133: sampling 2 individuals of OOA(p1)
# Generation 133: sampling 1 individuals of OOA(p1)
# Generation 133: sampling 1 individuals of OOA(p1)
# Generation 133: sampling 1 individuals of OOA(p1)
# Generation 133: sampling 1 individuals of OOA(p1)
# Generation 133: sampling 1 individuals of OOA(p1)
# Generation 133: sampling 1 individuals of OOA(p1)
# Generation 134: sampling 1 individuals of OOA(p1)
# Generation 134: sampling 1 individuals of OOA(p1)
# Generation 134: sampling 1 individuals of OOA(p1)
# Generation 134: sampling 1 individuals of OOA(p1)
# Generation 134: sampling 1 individuals of OOA(p1)
# Generation 134: sampling 1 individuals of OOA(p1)
# Generation 134: sampling 1 individuals of OOA(p1)
# Generation 134: sampling 1 individuals of OOA(p1)
# Generation 134: sampling 1 individuals of OOA(p1)
# Generation 134: sampling 1 individuals of OOA(p1)
# Generation 135: sampling 1 individuals of OOA(p1)
# Generation 135: sampling 1 individuals of OOA(p1)
# Generation 135: sampling 1 individuals of OOA(p1)
# Generation 135: sampling 1 individuals of OOA(p1)
# Generation 135: sampling 1 individuals of OOA(p1)
# Generation 135: sampling 1 individuals of OOA(p1)
# Generation 135: sampling 1 individuals of OOA(p1)
# Generation 136: sampling 1 individuals of OOA(p1)
# Generation 136: sampling 1 individuals of OOA(p1)
# Generation 136: sampling 1 individuals of OOA(p1)
# Generation 136: sampling 1 individuals of OOA(p1)
# Generation 136: sampling 1 individuals of OOA(p1)
# Generation 136: sampling 1 individuals of OOA(p1)
# Generation 136: sampling 1 individuals of OOA(p1)
# Generation 137: sampling 1 individuals of OOA(p1)
# Generation 137: sampling 1 individuals of OOA(p1)
# Generation 137: sampling 1 individuals of OOA(p1)
# Generation 137: sampling 1 individuals of OOA(p1)
# Generation 137: sampling 1 individuals of OOA(p1)
# Generation 137: sampling 1 individuals of OOA(p1)
# Generation 137: sampling 1 individuals of OOA(p1)
# Generation 137: sampling 1 individuals of OOA(p1)
# Generation 137: sampling 1 individuals of OOA(p1)
# Generation 138: sampling 1 individuals of OOA(p1)
# Generation 138: sampling 1 individuals of OOA(p1)
# Generation 138: sampling 2 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 139: sampling 2 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 139: sampling 1 individuals of OOA(p1)
# Generation 140: sampling 1 individuals of OOA(p1)
# Generation 140: sampling 1 individuals of OOA(p1)
# Generation 140: sampling 1 individuals of OOA(p1)
# Generation 140: sampling 1 individuals of OOA(p1)
# Generation 140: sampling 2 individuals of OOA(p1)
# Generation 140: sampling 2 individuals of OOA(p1)
# Generation 140: sampling 1 individuals of OOA(p1)
# Generation 141: sampling 1 individuals of OOA(p1)
# Generation 141: sampling 2 individuals of OOA(p1)
# Generation 141: sampling 1 individuals of OOA(p1)
# Generation 141: sampling 1 individuals of OOA(p1)
# Generation 141: sampling 1 individuals of OOA(p1)
# Generation 141: sampling 1 individuals of OOA(p1)
# Generation 141: sampling 1 individuals of OOA(p1)
# Generation 142: sampling 1 individuals of OOA(p1)
# Generation 142: sampling 1 individuals of OOA(p1)
# Generation 142: sampling 1 individuals of OOA(p1)
# Generation 142: sampling 1 individuals of OOA(p1)
# Generation 142: sampling 2 individuals of OOA(p1)
# Generation 142: sampling 1 individuals of OOA(p1)
# Generation 142: sampling 1 individuals of OOA(p1)
# Generation 142: sampling 1 individuals of OOA(p1)
# Generation 142: sampling 1 individuals of OOA(p1)
# Generation 142: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: sampling 1 individuals of OOA(p1)
# Generation 143: updating map for OOA(p1)
# Generation 144: sampling 1 individuals of OOA(p1)
# Generation 144: sampling 1 individuals of OOA(p1)
# Generation 144: sampling 1 individuals of OOA(p1)
# Generation 144: sampling 1 individuals of OOA(p1)
# Generation 144: sampling 1 individuals of OOA(p1)
# Generation 144: sampling 1 individuals of OOA(p1)
# Generation 144: sampling 1 individuals of OOA(p1)
# Generation 144: sampling 1 individuals of OOA(p1)
# Generation 144: sampling 1 individuals of OOA(p1)
# Generation 145: sampling 1 individuals of OOA(p1)
# Generation 145: sampling 1 individuals of OOA(p1)
# Generation 145: sampling 1 individuals of OOA(p1)
# Generation 145: sampling 1 individuals of OOA(p1)
# Generation 145: sampling 1 individuals of OOA(p1)
# Generation 145: sampling 1 individuals of OOA(p1)
# Generation 145: sampling 1 individuals of OOA(p1)
# Generation 145: sampling 1 individuals of OOA(p1)
# Generation 146: sampling 1 individuals of OOA(p1)
# Generation 146: sampling 1 individuals of OOA(p1)
# Generation 146: sampling 1 individuals of OOA(p1)
# Generation 146: sampling 2 individuals of OOA(p1)
# Generation 146: sampling 1 individuals of OOA(p1)
# Generation 146: sampling 1 individuals of OOA(p1)
# Generation 146: sampling 1 individuals of OOA(p1)
# Generation 146: sampling 1 individuals of OOA(p1)
# Generation 146: sampling 1 individuals of OOA(p1)
# Generation 147: sampling 1 individuals of OOA(p1)
# Generation 147: sampling 1 individuals of OOA(p1)
# Generation 147: sampling 2 individuals of OOA(p1)
# Generation 147: sampling 2 individuals of OOA(p1)
# Generation 147: sampling 1 individuals of OOA(p1)
# Generation 147: sampling 1 individuals of OOA(p1)
# Generation 147: sampling 1 individuals of OOA(p1)
# Generation 148: sampling 1 individuals of OOA(p1)
# Generation 148: sampling 1 individuals of OOA(p1)
# Generation 148: sampling 1 individuals of OOA(p1)
# Generation 148: sampling 1 individuals of OOA(p1)
# Generation 148: sampling 1 individuals of OOA(p1)
# Generation 148: sampling 1 individuals of OOA(p1)
# Generation 148: sampling 1 individuals of OOA(p1)
# Generation 149: sampling 1 individuals of OOA(p1)
# Generation 149: sampling 1 individuals of OOA(p1)
# Generation 149: sampling 1 individuals of OOA(p1)
# Generation 149: sampling 2 individuals of OOA(p1)
# Generation 150: sampling 1 individuals of OOA(p1)
# Generation 150: sampling 1 individuals of OOA(p1)
# Generation 150: sampling 1 individuals of OOA(p1)
# Generation 150: sampling 2 individuals of OOA(p1)
# Generation 150: sampling 1 individuals of OOA(p1)
# Generation 150: sampling 1 individuals of OOA(p1)
# Generation 150: sampling 1 individuals of OOA(p1)
# Generation 150: sampling 1 individuals of OOA(p1)
# Generation 150: sampling 1 individuals of OOA(p1)
# Generation 150: sampling 2 individuals of OOA(p1)
# Generation 150: sampling 1 individuals of OOA(p1)
# Generation 151: sampling 1 individuals of OOA(p1)
# Generation 151: sampling 2 individuals of OOA(p1)
# Generation 151: sampling 2 individuals of OOA(p1)
# Generation 151: sampling 1 individuals of OOA(p1)
# Generation 151: sampling 1 individuals of OOA(p1)
# Generation 151: sampling 1 individuals of OOA(p1)
# Generation 151: sampling 2 individuals of OOA(p1)
# Generation 151: sampling 1 individuals of OOA(p1)
# Generation 151: sampling 1 individuals of OOA(p1)
# Generation 151: sampling 1 individuals of OOA(p1)
# Generation 152: sampling 1 individuals of OOA(p1)
# Generation 152: sampling 1 individuals of OOA(p1)
# Generation 152: sampling 1 individuals of OOA(p1)
# Generation 152: sampling 1 individuals of OOA(p1)
# Generation 152: sampling 1 individuals of OOA(p1)
# Generation 152: sampling 1 individuals of OOA(p1)
# Generation 152: sampling 1 individuals of OOA(p1)
# Generation 152: sampling 1 individuals of OOA(p1)
# Generation 152: sampling 1 individuals of OOA(p1)
# Generation 152: sampling 1 individuals of OOA(p1)
# Generation 153: sampling 2 individuals of OOA(p1)
# Generation 153: sampling 1 individuals of OOA(p1)
# Generation 153: sampling 3 individuals of OOA(p1)
# Generation 153: sampling 1 individuals of OOA(p1)
# Generation 153: sampling 1 individuals of OOA(p1)
# Generation 153: sampling 1 individuals of OOA(p1)
# Generation 153: sampling 1 individuals of OOA(p1)
# Generation 154: sampling 1 individuals of OOA(p1)
# Generation 154: sampling 1 individuals of OOA(p1)
# Generation 154: sampling 1 individuals of OOA(p1)
# Generation 154: sampling 1 individuals of OOA(p1)
# Generation 154: sampling 1 individuals of OOA(p1)
# Generation 154: sampling 1 individuals of OOA(p1)
# Generation 154: sampling 1 individuals of OOA(p1)
# Generation 154: sampling 1 individuals of OOA(p1)
# ...
# Generation 1673: sampling 1 individuals of EUR(p4)
# Generation 1673: sampling 1 individuals of EUR(p4)
# Generation 1674: sampling 1 individuals of EUR(p4)
# Generation 1674: sampling 2 individuals of EUR(p4)
# Generation 1674: sampling 2 individuals of EUR(p4)
# Generation 1674: sampling 2 individuals of EUR(p4)
# Generation 1674: sampling 1 individuals of EUR(p4)
# Generation 1674: sampling 1 individuals of EUR(p4)
# Generation 1675: sampling 1 individuals of EUR(p4)
# Generation 1675: sampling 1 individuals of EUR(p4)
# Generation 1675: sampling 2 individuals of EUR(p4)
# Generation 1675: sampling 1 individuals of EUR(p4)
# Generation 1675: sampling 2 individuals of EUR(p4)
# Generation 1675: sampling 1 individuals of EUR(p4)
# Generation 1675: sampling 1 individuals of EUR(p4)
# Generation 1675: sampling 1 individuals of EUR(p4)
# Generation 1675: sampling 1 individuals of EUR(p4)
# Generation 1675: sampling 1 individuals of EUR(p4)
# Generation 1675: sampling 2 individuals of EUR(p4)
# Generation 1675: sampling 1 individuals of EUR(p4)
# Generation 1676: sampling 1 individuals of EUR(p4)
# Generation 1676: sampling 1 individuals of EUR(p4)
# Generation 1676: sampling 2 individuals of EUR(p4)
# Generation 1676: sampling 1 individuals of EUR(p4)
# Generation 1676: sampling 2 individuals of EUR(p4)
# Generation 1676: sampling 1 individuals of EUR(p4)
# Generation 1676: sampling 1 individuals of EUR(p4)
# Generation 1676: sampling 1 individuals of EUR(p4)
# Generation 1676: sampling 1 individuals of EUR(p4)
# Generation 1676: sampling 1 individuals of EUR(p4)
# Generation 1677: sampling 1 individuals of EUR(p4)
# Generation 1677: sampling 3 individuals of EUR(p4)
# Generation 1677: sampling 1 individuals of EUR(p4)
# Generation 1677: sampling 2 individuals of EUR(p4)
# Generation 1677: sampling 1 individuals of EUR(p4)
# Generation 1677: sampling 1 individuals of EUR(p4)
# Generation 1677: sampling 1 individuals of EUR(p4)
# Generation 1678: sampling 1 individuals of EUR(p4)
# Generation 1678: sampling 1 individuals of EUR(p4)
# Generation 1678: sampling 1 individuals of EUR(p4)
# Generation 1678: sampling 1 individuals of EUR(p4)
# Generation 1678: sampling 1 individuals of EUR(p4)
# Generation 1679: sampling 1 individuals of EUR(p4)
# Generation 1679: sampling 1 individuals of EUR(p4)
# Generation 1679: sampling 1 individuals of EUR(p4)
# Generation 1679: sampling 1 individuals of EUR(p4)
# Generation 1679: sampling 1 individuals of EUR(p4)
# Generation 1679: sampling 1 individuals of EUR(p4)
# Generation 1680: sampling 1 individuals of EUR(p4)
# Generation 1681: sampling 1 individuals of EUR(p4)
# Generation 1681: sampling 1 individuals of EUR(p4)
# Generation 1681: sampling 1 individuals of EUR(p4)
# Generation 1681: sampling 1 individuals of EUR(p4)
# Generation 1681: sampling 1 individuals of EUR(p4)
# Generation 1681: sampling 1 individuals of EUR(p4)
# Generation 1681: sampling 1 individuals of EUR(p4)
# Generation 1682: sampling 1 individuals of EUR(p4)
# Generation 1682: sampling 1 individuals of EUR(p4)
# Generation 1682: sampling 1 individuals of EUR(p4)
# Generation 1682: sampling 1 individuals of EUR(p4)
# Generation 1682: sampling 1 individuals of EUR(p4)
# Generation 1682: sampling 1 individuals of EUR(p4)
# Generation 1682: sampling 1 individuals of EUR(p4)
# Generation 1683: sampling 1 individuals of EUR(p4)
# Generation 1683: sampling 2 individuals of EUR(p4)
# Generation 1683: sampling 1 individuals of EUR(p4)
# Generation 1683: sampling 1 individuals of EUR(p4)
# Generation 1684: sampling 1 individuals of EUR(p4)
# Generation 1684: sampling 1 individuals of EUR(p4)
# Generation 1684: sampling 2 individuals of EUR(p4)
# Generation 1684: sampling 1 individuals of EUR(p4)
# Generation 1684: sampling 1 individuals of EUR(p4)
# Generation 1684: sampling 1 individuals of EUR(p4)
# Generation 1684: sampling 2 individuals of EUR(p4)
# Generation 1685: sampling 1 individuals of EUR(p4)
# Generation 1685: sampling 1 individuals of EUR(p4)
# Generation 1685: sampling 2 individuals of EUR(p4)
# Generation 1685: sampling 1 individuals of EUR(p4)
# Generation 1685: sampling 1 individuals of EUR(p4)
# Generation 1685: sampling 1 individuals of EUR(p4)
# Generation 1686: sampling 2 individuals of EUR(p4)
# Generation 1686: sampling 1 individuals of EUR(p4)
# Generation 1686: sampling 1 individuals of EUR(p4)
# Generation 1686: sampling 1 individuals of EUR(p4)
# Generation 1686: sampling 1 individuals of EUR(p4)
# Generation 1686: sampling 1 individuals of EUR(p4)
# Generation 1686: sampling 2 individuals of EUR(p4)
# Generation 1686: sampling 1 individuals of EUR(p4)
# Generation 1686: sampling 1 individuals of EUR(p4)
# Generation 1686: sampling 1 individuals of EUR(p4)
# Generation 1686: sampling 1 individuals of EUR(p4)
# Generation 1687: sampling 1 individuals of EUR(p4)
# Generation 1687: sampling 1 individuals of EUR(p4)
# Generation 1687: sampling 1 individuals of EUR(p4)
# Generation 1687: sampling 1 individuals of EUR(p4)
# Generation 1687: sampling 1 individuals of EUR(p4)
# Generation 1687: sampling 1 individuals of EUR(p4)
# Generation 1687: sampling 1 individuals of EUR(p4)
# Generation 1688: sampling 1 individuals of EUR(p4)
# Generation 1688: sampling 2 individuals of EUR(p4)
# Generation 1688: sampling 1 individuals of EUR(p4)
# Generation 1688: sampling 2 individuals of EUR(p4)
# Generation 1688: sampling 1 individuals of EUR(p4)
# Generation 1688: sampling 1 individuals of EUR(p4)
# Generation 1688: sampling 1 individuals of EUR(p4)
# Generation 1688: sampling 1 individuals of EUR(p4)
# Generation 1688: sampling 1 individuals of EUR(p4)
# Generation 1689: sampling 2 individuals of EUR(p4)
# Generation 1689: sampling 1 individuals of EUR(p4)
# Generation 1689: sampling 1 individuals of EUR(p4)
# Generation 1689: sampling 1 individuals of EUR(p4)
# Generation 1689: sampling 1 individuals of EUR(p4)
# Generation 1689: sampling 1 individuals of EUR(p4)
# Generation 1689: sampling 1 individuals of EUR(p4)
# Generation 1690: sampling 1 individuals of EUR(p4)
# Generation 1690: sampling 2 individuals of EUR(p4)
# Generation 1690: sampling 1 individuals of EUR(p4)
# Generation 1690: sampling 1 individuals of EUR(p4)
# Generation 1690: sampling 2 individuals of EUR(p4)
# Generation 1690: sampling 1 individuals of EUR(p4)
# Generation 1691: sampling 1 individuals of EUR(p4)
# Generation 1691: sampling 1 individuals of EUR(p4)
# Generation 1691: sampling 1 individuals of EUR(p4)
# Generation 1691: sampling 1 individuals of EUR(p4)
# Generation 1692: sampling 1 individuals of EUR(p4)
# Generation 1692: sampling 1 individuals of EUR(p4)
# Generation 1692: sampling 1 individuals of EUR(p4)
# Generation 1692: sampling 1 individuals of EUR(p4)
# Generation 1692: sampling 1 individuals of EUR(p4)
# Generation 1692: sampling 1 individuals of EUR(p4)
# Generation 1692: sampling 1 individuals of EUR(p4)
# Generation 1693: sampling 2 individuals of EUR(p4)
# Generation 1693: sampling 1 individuals of EUR(p4)
# Generation 1693: sampling 1 individuals of EUR(p4)
# Generation 1693: sampling 2 individuals of EUR(p4)
# Generation 1693: sampling 1 individuals of EUR(p4)
# Generation 1693: sampling 1 individuals of EUR(p4)
# Generation 1694: sampling 1 individuals of EUR(p4)
# Generation 1694: sampling 1 individuals of EUR(p4)
# Generation 1694: sampling 1 individuals of EUR(p4)
# Generation 1694: sampling 1 individuals of EUR(p4)
# Generation 1694: sampling 1 individuals of EUR(p4)
# Generation 1694: sampling 1 individuals of EUR(p4)
# Generation 1695: sampling 1 individuals of EUR(p4)
# Generation 1695: sampling 1 individuals of EUR(p4)
# Generation 1695: sampling 1 individuals of EUR(p4)
# Generation 1695: sampling 1 individuals of EUR(p4)
# Generation 1695: sampling 1 individuals of EUR(p4)
# Generation 1695: sampling 2 individuals of EUR(p4)
# Generation 1695: sampling 1 individuals of EUR(p4)
# Generation 1695: sampling 1 individuals of EUR(p4)
# Generation 1696: sampling 1 individuals of EUR(p4)
# Generation 1696: sampling 1 individuals of EUR(p4)
# Generation 1696: sampling 1 individuals of EUR(p4)
# Generation 1696: sampling 1 individuals of EUR(p4)
# Generation 1696: sampling 1 individuals of EUR(p4)
# Generation 1696: sampling 1 individuals of EUR(p4)
# Generation 1696: sampling 1 individuals of EUR(p4)
# Generation 1696: sampling 1 individuals of EUR(p4)
# Generation 1696: sampling 1 individuals of EUR(p4)
# Generation 1697: sampling 1 individuals of EUR(p4)
# Generation 1697: sampling 1 individuals of EUR(p4)
# Generation 1697: sampling 1 individuals of EUR(p4)
# Generation 1697: sampling 1 individuals of EUR(p4)
# Generation 1697: sampling 1 individuals of EUR(p4)
# Generation 1697: sampling 1 individuals of EUR(p4)
# Generation 1697: sampling 2 individuals of EUR(p4)
# Generation 1697: sampling 2 individuals of EUR(p4)
# Generation 1697: sampling 2 individuals of EUR(p4)
# Generation 1698: sampling 2 individuals of EUR(p4)
# Generation 1698: sampling 2 individuals of EUR(p4)
# Generation 1698: sampling 1 individuals of EUR(p4)
# Generation 1698: sampling 1 individuals of EUR(p4)
# Generation 1698: sampling 1 individuals of EUR(p4)
# Generation 1698: sampling 1 individuals of EUR(p4)
# Generation 1699: sampling 1 individuals of EUR(p4)
# Generation 1699: sampling 1 individuals of EUR(p4)
# Generation 1699: sampling 1 individuals of EUR(p4)
# Generation 1699: sampling 1 individuals of EUR(p4)
# Generation 1700: sampling 1 individuals of EUR(p4)
# Generation 1700: sampling 1 individuals of EUR(p4)
# Generation 1700: sampling 1 individuals of EUR(p4)
# Generation 1700: sampling 1 individuals of EUR(p4)
# Generation 1700: sampling 1 individuals of EUR(p4)
# Generation 1700: sampling 1 individuals of EUR(p4)
# Generation 1700: sampling 1 individuals of EUR(p4)
# Generation 1700: sampling 1 individuals of EUR(p4)
# Generation 1701: sampling 1 individuals of EUR(p4)
# Generation 1701: sampling 1 individuals of EUR(p4)
# Generation 1701: sampling 2 individuals of EUR(p4)
# Generation 1701: sampling 1 individuals of EUR(p4)
# Generation 1701: sampling 2 individuals of EUR(p4)
# Generation 1701: sampling 1 individuals of EUR(p4)
# Generation 1701: sampling 1 individuals of EUR(p4)
# Generation 1701: sampling 1 individuals of EUR(p4)
# Generation 1702: sampling 1 individuals of EUR(p4)
# Generation 1702: sampling 1 individuals of EUR(p4)
# Generation 1702: sampling 2 individuals of EUR(p4)
# Generation 1702: sampling 1 individuals of EUR(p4)
# Generation 1702: sampling 1 individuals of EUR(p4)
# Generation 1702: sampling 1 individuals of EUR(p4)
# Generation 1702: sampling 2 individuals of EUR(p4)
# Generation 1703: sampling 1 individuals of EUR(p4)
# Generation 1703: sampling 1 individuals of EUR(p4)
# Generation 1703: sampling 1 individuals of EUR(p4)
# Generation 1703: sampling 1 individuals of EUR(p4)
# Generation 1703: sampling 1 individuals of EUR(p4)
# Generation 1704: sampling 1 individuals of EUR(p4)
# Generation 1704: sampling 1 individuals of EUR(p4)
# Generation 1704: sampling 1 individuals of EUR(p4)
# Generation 1705: sampling 1 individuals of EUR(p4)
# Generation 1705: sampling 1 individuals of EUR(p4)
# Generation 1705: sampling 2 individuals of EUR(p4)
# Generation 1705: sampling 2 individuals of EUR(p4)
# Generation 1705: sampling 1 individuals of EUR(p4)
# Generation 1705: sampling 1 individuals of EUR(p4)
# Generation 1705: sampling 1 individuals of EUR(p4)
# Generation 1705: sampling 1 individuals of EUR(p4)
# Generation 1705: sampling 1 individuals of EUR(p4)
# Generation 1706: sampling 1 individuals of EUR(p4)
# Generation 1706: sampling 1 individuals of EUR(p4)
# Generation 1706: sampling 1 individuals of EUR(p4)
# Generation 1706: sampling 1 individuals of EUR(p4)
# Generation 1706: sampling 1 individuals of EUR(p4)
# Generation 1706: sampling 1 individuals of EUR(p4)
# Generation 1707: sampling 1 individuals of EUR(p4)
# Generation 1707: sampling 1 individuals of EUR(p4)
# Generation 1707: sampling 2 individuals of EUR(p4)
# Generation 1707: sampling 2 individuals of EUR(p4)
# Generation 1707: sampling 1 individuals of EUR(p4)
# Generation 1707: sampling 1 individuals of EUR(p4)
# Generation 1707: sampling 1 individuals of EUR(p4)
# Generation 1707: sampling 1 individuals of EUR(p4)
# Generation 1707: sampling 1 individuals of EUR(p4)
# Generation 1707: sampling 1 individuals of EUR(p4)
# Generation 1707: sampling 1 individuals of EUR(p4)
# Generation 1708: sampling 1 individuals of EUR(p4)
# Generation 1708: sampling 1 individuals of EUR(p4)
# Generation 1708: sampling 2 individuals of EUR(p4)
# Generation 1708: sampling 1 individuals of EUR(p4)
# Generation 1708: sampling 1 individuals of EUR(p4)
# Generation 1708: sampling 1 individuals of EUR(p4)
# Generation 1708: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 2 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1709: sampling 1 individuals of EUR(p4)
# Generation 1710: sampling 1 individuals of EUR(p4)
# Generation 1710: sampling 1 individuals of EUR(p4)
# Generation 1710: sampling 1 individuals of EUR(p4)
# Generation 1710: sampling 1 individuals of EUR(p4)
# Generation 1710: sampling 1 individuals of EUR(p4)
# Generation 1710: sampling 1 individuals of EUR(p4)
# Generation 1710: sampling 2 individuals of EUR(p4)
# Generation 1710: sampling 1 individuals of EUR(p4)
# Generation 1710: sampling 1 individuals of EUR(p4)
# Generation 1711: sampling 1 individuals of EUR(p4)
# Generation 1711: sampling 1 individuals of EUR(p4)
# Generation 1711: sampling 1 individuals of EUR(p4)
# Generation 1711: sampling 1 individuals of EUR(p4)
# Generation 1712: sampling 1 individuals of EUR(p4)
# Generation 1712: sampling 1 individuals of EUR(p4)
# Generation 1712: sampling 1 individuals of EUR(p4)
# Generation 1712: sampling 1 individuals of EUR(p4)
# Generation 1712: sampling 1 individuals of EUR(p4)
# Generation 1712: sampling 1 individuals of EUR(p4)
# Generation 1712: sampling 1 individuals of EUR(p4)
# Generation 1713: sampling 1 individuals of EUR(p4)
# Generation 1713: sampling 1 individuals of EUR(p4)
# Generation 1713: sampling 1 individuals of EUR(p4)
# Generation 1713: sampling 1 individuals of EUR(p4)
# Generation 1713: sampling 2 individuals of EUR(p4)
# Generation 1713: sampling 1 individuals of EUR(p4)
# Generation 1713: sampling 1 individuals of EUR(p4)
# Generation 1713: sampling 1 individuals of EUR(p4)
# Generation 1713: sampling 1 individuals of EUR(p4)
# Generation 1713: sampling 1 individuals of EUR(p4)
# Generation 1713: sampling 1 individuals of EUR(p4)
# Generation 1714: sampling 1 individuals of EUR(p4)
# Generation 1714: sampling 1 individuals of EUR(p4)
# Generation 1714: sampling 1 individuals of EUR(p4)
# Generation 1714: sampling 1 individuals of EUR(p4)
# Generation 1714: sampling 1 individuals of EUR(p4)
# Generation 1714: sampling 1 individuals of EUR(p4)
# Generation 1714: sampling 1 individuals of EUR(p4)
# Generation 1715: sampling 1 individuals of EUR(p4)
# Generation 1715: sampling 1 individuals of EUR(p4)
# Generation 1715: sampling 1 individuals of EUR(p4)
# Generation 1715: sampling 2 individuals of EUR(p4)
# Generation 1716: sampling 1 individuals of EUR(p4)
# Generation 1716: sampling 1 individuals of EUR(p4)
# Generation 1716: sampling 1 individuals of EUR(p4)
# Generation 1716: sampling 1 individuals of EUR(p4)
# Generation 1716: sampling 2 individuals of EUR(p4)
# Generation 1716: sampling 1 individuals of EUR(p4)
# Generation 1716: sampling 1 individuals of EUR(p4)
# Generation 1716: sampling 1 individuals of EUR(p4)
# Generation 1716: sampling 1 individuals of EUR(p4)
# Generation 1717: sampling 1 individuals of EUR(p4)
# Generation 1717: sampling 1 individuals of EUR(p4)
# Generation 1717: sampling 1 individuals of EUR(p4)
# Generation 1717: sampling 1 individuals of EUR(p4)
# Generation 1718: sampling 1 individuals of EUR(p4)
# Generation 1718: sampling 1 individuals of EUR(p4)
# Generation 1734: saving the tree sequence output
# Generation 1734: simulation finished

# %%
# %%R
#
# #This was created with a simulation with N = 1500 instead of N = 15000.
#
# #if(!file.exists(paste(simulation_path, "sim.gif", sep = ""))){
# #    animate_model(model = model, steps = 100, width = 500, height = 300, gif = paste(simulation_path, "sim.gif", sep = ""))
# #}
# Out:
# NULL

# %% [markdown]
# ![](../data/europe/sim.gif "gif")

# %% [markdown]
# [<img src="arrow.png" width="100" style="float: left;">](#Home) &nbsp;
#
# &nbsp;
#
# <a name="Out"></a>
# ### G. Output
#
# In this section I just check that the metadata for the nodes simulated seems correct. For that, I just plot the latitude and longitude over a map to see if the sampled individuals map to where they are supposed to.

# %%
# %%R
#
# read.table("../../data/europe/metadata.txt", header = T) -> metadata
#
# metadata %>% head()
# Out:
#   ind_id pop  time sampled      lat      lon node1 node2
# 1     78 OOA 50959       1 27.03430 31.54521     0     1
# 2     79 OOA 50957       1 27.97961 31.63202     2     3
# 3     80 OOA 50948       1 29.36448 29.72894     4     5
# 4     81 OOA 50946       1 30.93615 30.79358     6     7
# 5     82 OOA 50941       1 31.21969 34.35055     8     9
# 6     83 OOA 50941       1 30.94297 31.54401    10    11

# %%
# %%R -w 1500 -h 750
# world <- ne_countries(scale = "medium", returnclass = "sf")
#
# metadata %>%
#     mutate(time = trunc(time/5000)) %>%
#     ggplot() +
#     geom_sf(data = world) +
#     coord_sf(xlim = c(-25, 70), ylim = c(20, 80), expand = FALSE) +
#     geom_point(aes(x = lon, y = lat, color = pop), alpha = 0.75) +
#     #geom_density_2d(data = . %>% group_by(time, pop), aes(x = lon, y = lat)) +
#     facet_grid(pop~time) +
#     theme_bw() +
#     scale_color_manual(values=col_pop) +
#     xlab("Longitude") +
#     ylab("Latitude")

# %% [markdown]
# [<img src="arrow.png" width="100" style="float: left;">](#Home) &nbsp;
#
# &nbsp;
